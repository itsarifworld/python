# %% [markdown]
# <a href="https://colab.research.google.com/github/itsarifworld/python/blob/main/prob_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import random

# %% [markdown]
# ROLLING 1 DICE

# %%
L = []
for i in range(10000):
  L.append(random.randint(1,6))
len(L)
# Out:
# 10000

# %%
s = (pd.Series(L).value_counts()/pd.Series(L).value_counts().sum()).sort_index()

# %%
s.plot(kind = 'bar')
# Out:
# <Axes: >

# %% [markdown]
# ROLLING 2 DICES

# %%
L = []
for i in range(10000):
  a = random.randint(1,6)
  b = random.randint(1,6)

  L.append(a + b)

# %%
len(L)
# Out:
# 10000

# %%
L[:5]
# Out:
# [7, 6, 3, 7, 6]

# %%
s = (pd.Series(L).value_counts()/pd.Series(L).value_counts().sum()).sort_index()

# %%
s.plot(kind = 'bar')
# Out:
# <Axes: >

# %%
import numpy as np
np.cumsum(s).plot(kind = 'bar')
# Out:
# <Axes: >

# %% [markdown]
# PARAMETIC DENSITY ESTIMATION

# %%
import matplotlib.pyplot as plt
import numpy as np
from numpy.random import normal


# MEAN = 50 (POPULATION)
# STANDARD DEVIATION = 5 ( POPULATION )
sample = normal(loc=50, scale=5, size=1000)

# %%
sample.mean()
# Out:
# np.float64(49.83959422890615)

# %%
plt.hist(sample, bins=10)
# Out:
# (array([  1.,   6.,  56., 126., 241., 247., 181., 100.,  35.,   7.]),
#  array([31.90317092, 35.2666083 , 38.63004568, 41.99348306, 45.35692043,
#         48.72035781, 52.08379519, 55.44723256, 58.81066994, 62.17410732,
#         65.5375447 ]),
#  <BarContainer object of 10 artists>)

# %%
sample_mean = sample.mean()
sample_std = sample.std()

# %%
from scipy.stats import norm
dist = norm(sample_mean, sample_std)

# %%
values = np.linspace(sample.min(), sample.max())

# %%
prob_dense = [dist.pdf(value) for value in values]

# %%
plt.hist(sample, bins = 10, density = True)
plt.plot(values, prob_dense)

# %%
import seaborn as sns
sns.distplot(sample)
# Out:
# /tmp/ipython-input-1482356190.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(sample)
# <Axes: ylabel='Density'>
